# %%
print("Hello Rutvik!")
# Out:
# Hello Rutvik!

# %%
# version of python
import sys
print("Python Version: ")
print(sys.version)
# Out:
# Python Version:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
import platform

import sys
import keyword
from datetime import datetime

print("Python Version :",platform.python_version())

print("Python Build : ",platform.python_build())

print("Python Compiler: ",platform.python_compiler())

print("Python Implementation: ",platform.python_implementation())

print("Operating System: ",platform.system())
print("OS Version: ",platform.version())

print("Machine: ",platform.machine())
print("Processor: ",platform.processor())

print("Python Executable Path: ",sys.executable)
print("Python Module Path: ",sys.path)
print("Python Version: ",sys.version)


print("Python Keywords List",keyword.kwlist)

print("Current Date and Time: ",datetime.now())
# Out:
# Python Version : 3.12.13
# Python Build :  ('main', 'Mar  4 2026 09:23:07')
# Python Compiler:  GCC 11.4.0
# Python Implementation:  CPython
# Operating System:  Linux
# OS Version:  #1 SMP Mon Feb  2 12:27:57 UTC 2026
# Machine:  x86_64
# Processor:  x86_64
# Python Executable Path:  /usr/bin/python3
# Python Module Path:  ['/content', '/env/python', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.12/dist-packages/IPython/extensions', '/root/.ipython']
# Python Version:  3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Python Keywords List ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# Current Date and Time:  2026-04-07 10:36:33.099250

# %%
# !git clone https://github.com/BabariyaRutvik/BCA_SEM_3.git
# Out:
# Cloning into 'BCA_SEM_3'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 33 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 10.37 KiB | 10.37 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive
# Out:
# 'Colab Notebooks'

# %%
import shutil
shutil.copy('/content/drive/MyDrive/BCA Practice.ipynb', '/content/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_783/3132610590.py in <cell line: 0>()
#       1 import shutil
# ----> 2 shutil.copy('/content/drive/MyDrive/BCA Practice.ipynb', '/content/')
#
# /usr/lib/python3.12/shutil.py in copy(src, dst, follow_symlinks)
#     433     if os.path.isdir(dst):
#     434         dst = os.path.join(dst, os.path.basename(src))
# --> 435     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436     copymode(src, dst, follow_symlinks=follow_symlinks)
#     437     return dst
#
# /usr/lib/python3.12/shutil.py in copyfile(src, dst, follow_symlinks)
#     258         os.symlink(os.readlink(src), dst)
#     259     else:
# --> 260         with open(src, 'rb') as fsrc:
#     261             try:
#     262                 with open(dst, 'wb') as fdst:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/BCA Practice.ipynb'
